# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Training data
X = np.array([[1], [2], [3], [4], [5]])  # Years of experience (2D)
y = np.array([30000, 35000, 40000, 45000, 50000])  # Salary (1D)

# %%
# Create and train the model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predict salary for 6 years of experience
experience = 6
predicted_salary = model.predict([[experience]])
print(f"Predicted salary for {experience} years of experience: ${predicted_salary[0]:.2f}")
# Out:
# Predicted salary for 6 years of experience: $55000.00

# %%
# Plot the data
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='blue', label='Training data')  # Original data
plt.plot(X, model.predict(X), color='red', label='Best fit line')  # Regression line
plt.scatter([[experience]], predicted_salary, color='green', s=100, label=f'Prediction ({experience} yrs)')  # New prediction

# Add labels and show plot
plt.title("Linear Regression: Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.grid(True)
plt.show()
